# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 730

# %%
# Import the requests library.

import requests
requests.__version__


# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          #"Date": city_date,
                          "Current description": city_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hasaki
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | qaanaaq
# Processing Record 4 of Set 1 | pevek
# Processing Record 5 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 6 of Set 1 | hastings
# Processing Record 7 of Set 1 | golden
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | paracatu
# Processing Record 10 of Set 1 | touros
# Processing Record 11 of Set 1 | mar del plata
# Processing Record 12 of Set 1 | husavik
# Processing Record 13 of Set 1 | samarai
# Processing Record 14 of Set 1 | fort myers beach
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | aklavik
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | carnarvon
# Processing Record 19 of Set 1 | los llanos de aridane
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | tuktoyaktuk
# Processing Record 22 of Set 1 | tilichiki
# Processing Record 23 of Set 1 | constitucion
# Processing Record 24 of Set 1 | hobart
# Processing Record 25 of Set 1 | bluff
# Processing Record 26 of Set 1 | crab hill
# City not found. Skipping...
# Processing Record 27 of Set 1 | ruidoso
# Processing Record 28 of Set 1 | cabo san lucas
# Processing Record 29 of Set 1 | cockburn town
# Processing Record 30 of Set 1 | kurilsk
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | camacha
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | sibu
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | arraial do cabo
# Processing Record 40 of Set 1 | tuatapere
# Processing Record 41 of Set 1 | saint-francois
# Processing Record 42 of Set 1 | kodinar
# Processing Record 43 of Set 1 | hovd
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | alice springs
# Processing Record 46 of Set 1 | provideniya
# Processing Record 47 of Set 1 | isangel
# Processing Record 48 of Set 1 | inhambane
# Processing Record 49 of Set 1 | porto novo
# Processing Record 50 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 2 | clyde river
# Processing Record 2 of Set 2 | hukuntsi
# Processing Record 3 of Set 2 | puerto escondido
# Processing Record 4 of Set 2 | terrace
# Processing Record 5 of Set 2 | huautla
# Processing Record 6 of Set 2 | bethel
# Processing Record 7 of Set 2 | mahebourg
# Processing Record 8 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 9 of Set 2 | avarua
# Processing Record 10 of Set 2 | cabedelo
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 2 | coronado
# Processing Record 14 of Set 2 | bengkulu
# Processing Record 15 of Set 2 | kahului
# Processing Record 16 of Set 2 | ponta do sol
# Processing Record 17 of Set 2 | kavieng
# Processing Record 18 of Set 2 | dikson
# Processing Record 19 of Set 2 | auki
# Processing Record 20 of Set 2 | kawalu
# Processing Record 21 of Set 2 | chokurdakh
# Processing Record 22 of Set 2 | mountain home
# Processing Record 23 of Set 2 | narsaq
# Processing Record 24 of Set 2 | suluq
# Processing Record 25 of Set 2 | upernavik
# Processing Record 26 of Set 2 | alta floresta
# Processing Record 27 of Set 2 | tevaitoa
# Processing Record 28 of Set 2 | hambantota
# Processing Record 29 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 2 | camabatela
# Processing Record 31 of Set 2 | kungurtug
# Processing Record 32 of Set 2 | alofi
# Processing Record 33 of Set 2 | vysokogornyy
# Processing Record 34 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 2 | shelburne
# Processing Record 36 of Set 2 | cherskiy
# Processing Record 37 of Set 2 | new norfolk
# Processing Record 38 of Set 2 | ipixuna
# Processing Record 39 of Set 2 | atambua
# Processing Record 40 of Set 2 | nikolskoye
# Processing Record 41 of Set 2 | airai
# Processing Record 42 of Set 2 | puerto ayora
# Processing Record 43 of Set 2 | nouadhibou
# Processing Record 44 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 45 of Set 2 | georgetown
# Processing Record 46 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 2 | lasa
# Processing Record 48 of Set 2 | vaini
# Processing Record 49 of Set 2 | longyearbyen
# Processing Record 50 of Set 2 | sao joao da barra
# Processing Record 1 of Set 3 | bang saphan
# Processing Record 2 of Set 3 | atuona
# Processing Record 3 of Set 3 | kamina
# Processing Record 4 of Set 3 | ahuimanu
# Processing Record 5 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 3 | muros
# Processing Record 7 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 3 | omsukchan
# Processing Record 9 of Set 3 | buchanan
# Processing Record 10 of Set 3 | kapaa
# Processing Record 11 of Set 3 | klaksvik
# Processing Record 12 of Set 3 | faanui
# Processing Record 13 of Set 3 | ribeira grande
# Processing Record 14 of Set 3 | dauriya
# Processing Record 15 of Set 3 | hamilton
# Processing Record 16 of Set 3 | tiksi
# Processing Record 17 of Set 3 | el playon
# Processing Record 18 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 3 | massa marittima
# Processing Record 20 of Set 3 | la colmena
# Processing Record 21 of Set 3 | lebu
# Processing Record 22 of Set 3 | siverskiy
# Processing Record 23 of Set 3 | jacmel
# Processing Record 24 of Set 3 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 25 of Set 3 | cidreira
# Processing Record 26 of Set 3 | fortuna
# Processing Record 27 of Set 3 | sitka
# Processing Record 28 of Set 3 | cape town
# Processing Record 29 of Set 3 | imbituba
# Processing Record 30 of Set 3 | souillac
# Processing Record 31 of Set 3 | cabra
# Processing Record 32 of Set 3 | aswan
# Processing Record 33 of Set 3 | gazojak
# Processing Record 34 of Set 3 | leningradskiy
# Processing Record 35 of Set 3 | port alfred
# Processing Record 36 of Set 3 | yantikovo
# Processing Record 37 of Set 3 | tabou
# Processing Record 38 of Set 3 | thompson
# Processing Record 39 of Set 3 | rio gallegos
# Processing Record 40 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 3 | abha
# Processing Record 42 of Set 3 | dwarka
# Processing Record 43 of Set 3 | ha giang
# Processing Record 44 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 3 | kalianget
# Processing Record 46 of Set 3 | xining
# Processing Record 47 of Set 3 | kosovska mitrovica
# Processing Record 48 of Set 3 | sabang
# Processing Record 49 of Set 3 | itarema
# Processing Record 50 of Set 3 | cape elizabeth
# City not found. Skipping...
# Processing Record 1 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 4 | caravelas
# Processing Record 4 of Set 4 | sioux lookout
# Processing Record 5 of Set 4 | torbay
# Processing Record 6 of Set 4 | lompoc
# Processing Record 7 of Set 4 | victoria
# Processing Record 8 of Set 4 | san vicente
# Processing Record 9 of Set 4 | oktyabrskiy
# Processing Record 10 of Set 4 | kupang
# Processing Record 11 of Set 4 | waddan
# Processing Record 12 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 13 of Set 4 | houma
# Processing Record 14 of Set 4 | merauke
# Processing Record 15 of Set 4 | lapeer
# Processing Record 16 of Set 4 | ostrovnoy
# Processing Record 17 of Set 4 | vila
# Processing Record 18 of Set 4 | tadpatri
# Processing Record 19 of Set 4 | vao
# Processing Record 20 of Set 4 | tiruvottiyur
# City not found. Skipping...
# Processing Record 21 of Set 4 | saint-junien
# Processing Record 22 of Set 4 | atasu
# Processing Record 23 of Set 4 | katsuura
# Processing Record 24 of Set 4 | guisa
# Processing Record 25 of Set 4 | puerto narino
# Processing Record 26 of Set 4 | honningsvag
# Processing Record 27 of Set 4 | morwell
# Processing Record 28 of Set 4 | zaltan
# Processing Record 29 of Set 4 | yellowknife
# Processing Record 30 of Set 4 | kaitangata
# Processing Record 31 of Set 4 | dunedin
# Processing Record 32 of Set 4 | vuktyl
# Processing Record 33 of Set 4 | khatanga
# Processing Record 34 of Set 4 | mahadday weyne
# City not found. Skipping...
# Processing Record 35 of Set 4 | yar-sale
# Processing Record 36 of Set 4 | zonguldak
# Processing Record 37 of Set 4 | rivne
# Processing Record 38 of Set 4 | otane
# Processing Record 39 of Set 4 | qeshm
# Processing Record 40 of Set 4 | rochegda
# Processing Record 41 of Set 4 | amazar
# Processing Record 42 of Set 4 | bambous virieux
# Processing Record 43 of Set 4 | rogun
# City not found. Skipping...
# Processing Record 44 of Set 4 | altay
# Processing Record 45 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 46 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 47 of Set 4 | norman wells
# Processing Record 48 of Set 4 | san cristobal
# Processing Record 49 of Set 4 | haines junction
# Processing Record 50 of Set 4 | tromso
# Processing Record 1 of Set 5 | sotnikovskoye
# Processing Record 2 of Set 5 | tondano
# Processing Record 3 of Set 5 | paamiut
# Processing Record 4 of Set 5 | agirish
# Processing Record 5 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 5 | suntar
# Processing Record 7 of Set 5 | taganak
# Processing Record 8 of Set 5 | perbaungan
# Processing Record 9 of Set 5 | ulaangom
# Processing Record 10 of Set 5 | port elizabeth
# Processing Record 11 of Set 5 | redlands
# Processing Record 12 of Set 5 | saskylakh
# Processing Record 13 of Set 5 | naftah
# City not found. Skipping...
# Processing Record 14 of Set 5 | geraldton
# Processing Record 15 of Set 5 | iqaluit
# Processing Record 16 of Set 5 | talnakh
# Processing Record 17 of Set 5 | eldorado
# Processing Record 18 of Set 5 | bundi
# Processing Record 19 of Set 5 | beira
# Processing Record 20 of Set 5 | sao miguel do araguaia
# Processing Record 21 of Set 5 | port hardy
# Processing Record 22 of Set 5 | camacupa
# Processing Record 23 of Set 5 | la ronge
# Processing Record 24 of Set 5 | senanga
# Processing Record 25 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 5 | bathsheba
# Processing Record 27 of Set 5 | farmington
# Processing Record 28 of Set 5 | nizwa
# Processing Record 29 of Set 5 | east london
# Processing Record 30 of Set 5 | lubao
# Processing Record 31 of Set 5 | bredasdorp
# Processing Record 32 of Set 5 | tadine
# Processing Record 33 of Set 5 | margate
# Processing Record 34 of Set 5 | osorno
# Processing Record 35 of Set 5 | severo-kurilsk
# Processing Record 36 of Set 5 | tautira
# Processing Record 37 of Set 5 | bukene
# Processing Record 38 of Set 5 | penzance
# Processing Record 39 of Set 5 | rozhyshche
# Processing Record 40 of Set 5 | kabompo
# Processing Record 41 of Set 5 | mount isa
# Processing Record 42 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 43 of Set 5 | aljezur
# Processing Record 44 of Set 5 | barra do garcas
# Processing Record 45 of Set 5 | marystown
# Processing Record 46 of Set 5 | lata
# Processing Record 47 of Set 5 | kibala
# Processing Record 48 of Set 5 | cassilandia
# Processing Record 49 of Set 5 | talara
# Processing Record 50 of Set 5 | lagoa
# Processing Record 1 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 6 | kodiak
# Processing Record 3 of Set 6 | khani
# Processing Record 4 of Set 6 | ituni
# City not found. Skipping...
# Processing Record 5 of Set 6 | oyem
# Processing Record 6 of Set 6 | ixtapa
# Processing Record 7 of Set 6 | dalvik
# Processing Record 8 of Set 6 | cayenne
# Processing Record 9 of Set 6 | maragogi
# Processing Record 10 of Set 6 | nuevo laredo
# Processing Record 11 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 6 | mayo
# Processing Record 13 of Set 6 | tungor
# Processing Record 14 of Set 6 | newala
# Processing Record 15 of Set 6 | dullewala
# Processing Record 16 of Set 6 | padang
# Processing Record 17 of Set 6 | roma
# Processing Record 18 of Set 6 | havoysund
# Processing Record 19 of Set 6 | tasiilaq
# Processing Record 20 of Set 6 | borba
# Processing Record 21 of Set 6 | juye
# Processing Record 22 of Set 6 | henties bay
# Processing Record 23 of Set 6 | palana
# Processing Record 24 of Set 6 | sao filipe
# Processing Record 25 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 6 | pangnirtung
# Processing Record 27 of Set 6 | chivay
# Processing Record 28 of Set 6 | newport
# Processing Record 29 of Set 6 | yomitan
# City not found. Skipping...
# Processing Record 30 of Set 6 | barrow
# Processing Record 31 of Set 6 | saldanha
# Processing Record 32 of Set 6 | sudbury
# Processing Record 33 of Set 6 | esperance
# Processing Record 34 of Set 6 | kavaratti
# Processing Record 35 of Set 6 | marsh harbour
# Processing Record 36 of Set 6 | hadejia
# Processing Record 37 of Set 6 | ilorin
# Processing Record 38 of Set 6 | port macquarie
# Processing Record 39 of Set 6 | thessalon
# Processing Record 40 of Set 6 | ambon
# Processing Record 41 of Set 6 | hudiksvall
# Processing Record 42 of Set 6 | oka
# Processing Record 43 of Set 6 | seoul
# Processing Record 44 of Set 6 | eenhana
# Processing Record 45 of Set 6 | tabuk
# Processing Record 46 of Set 6 | ketchikan
# Processing Record 47 of Set 6 | beloha
# Processing Record 48 of Set 6 | freeport
# Processing Record 49 of Set 6 | mackay
# Processing Record 50 of Set 6 | umm kaddadah
# Processing Record 1 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 7 | wilmington
# Processing Record 3 of Set 7 | thunder bay
# Processing Record 4 of Set 7 | osoyoos
# Processing Record 5 of Set 7 | desaguadero
# Processing Record 6 of Set 7 | gafargaon
# Processing Record 7 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 8 of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record 9 of Set 7 | pochutla
# Processing Record 10 of Set 7 | taoudenni
# Processing Record 11 of Set 7 | navirai
# Processing Record 12 of Set 7 | ankang
# Processing Record 13 of Set 7 | kulachi
# Processing Record 14 of Set 7 | altamira
# Processing Record 15 of Set 7 | meulaboh
# Processing Record 16 of Set 7 | turukhansk
# Processing Record 17 of Set 7 | jagadhri
# Processing Record 18 of Set 7 | college
# Processing Record 19 of Set 7 | luderitz
# Processing Record 20 of Set 7 | barao de melgaco
# Processing Record 21 of Set 7 | nuuk
# Processing Record 22 of Set 7 | belyy yar
# Processing Record 23 of Set 7 | port-gentil
# Processing Record 24 of Set 7 | salalah
# Processing Record 25 of Set 7 | moron
# Processing Record 26 of Set 7 | zachagansk
# City not found. Skipping...
# Processing Record 27 of Set 7 | dutse
# Processing Record 28 of Set 7 | kimbe
# Processing Record 29 of Set 7 | pundaguitan
# Processing Record 30 of Set 7 | mount gambier
# Processing Record 31 of Set 7 | porto santo
# Processing Record 32 of Set 7 | bima
# Processing Record 33 of Set 7 | gillette
# Processing Record 34 of Set 7 | howell
# Processing Record 35 of Set 7 | puro
# Processing Record 36 of Set 7 | gravdal
# Processing Record 37 of Set 7 | grand gaube
# Processing Record 38 of Set 7 | tsumeb
# Processing Record 39 of Set 7 | koslan
# Processing Record 40 of Set 7 | rezina
# Processing Record 41 of Set 7 | masoko
# Processing Record 42 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 7 | kulhudhuffushi
# Processing Record 45 of Set 7 | contamana
# Processing Record 46 of Set 7 | zyryanka
# Processing Record 47 of Set 7 | rocha
# Processing Record 48 of Set 7 | todos santos
# Processing Record 49 of Set 7 | san andres
# Processing Record 50 of Set 7 | makinsk
# Processing Record 1 of Set 8 | karratha
# Processing Record 2 of Set 8 | christchurch
# Processing Record 3 of Set 8 | ossora
# Processing Record 4 of Set 8 | kruisfontein
# Processing Record 5 of Set 8 | wooster
# Processing Record 6 of Set 8 | chuy
# Processing Record 7 of Set 8 | brae
# Processing Record 8 of Set 8 | codrington
# Processing Record 9 of Set 8 | viramgam
# Processing Record 10 of Set 8 | svetlyy
# Processing Record 11 of Set 8 | dingle
# Processing Record 12 of Set 8 | eyl
# Processing Record 13 of Set 8 | hofn
# Processing Record 14 of Set 8 | murgab
# Processing Record 15 of Set 8 | dhidhdhoo
# Processing Record 16 of Set 8 | lavrentiya
# Processing Record 17 of Set 8 | te anau
# Processing Record 18 of Set 8 | ponta delgada
# Processing Record 19 of Set 8 | san policarpo
# Processing Record 20 of Set 8 | saint-philippe
# Processing Record 21 of Set 8 | spencer
# Processing Record 22 of Set 8 | qandala
# Processing Record 23 of Set 8 | sinnamary
# Processing Record 24 of Set 8 | nayoro
# Processing Record 25 of Set 8 | chicama
# Processing Record 26 of Set 8 | harper
# Processing Record 27 of Set 8 | san jose
# Processing Record 28 of Set 8 | adrar
# Processing Record 29 of Set 8 | pacific grove
# Processing Record 30 of Set 8 | poum
# Processing Record 31 of Set 8 | araouane
# Processing Record 32 of Set 8 | sawakin
# Processing Record 33 of Set 8 | bonavista
# Processing Record 34 of Set 8 | bom sucesso
# Processing Record 35 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 36 of Set 8 | sapouy
# Processing Record 37 of Set 8 | sur
# Processing Record 38 of Set 8 | jiuquan
# Processing Record 39 of Set 8 | odweyne
# Processing Record 40 of Set 8 | goundam
# Processing Record 41 of Set 8 | vitim
# Processing Record 42 of Set 8 | andra
# Processing Record 43 of Set 8 | ozgon
# City not found. Skipping...
# Processing Record 44 of Set 8 | arlit
# Processing Record 45 of Set 8 | bury saint edmunds
# City not found. Skipping...
# Processing Record 46 of Set 8 | alamosa
# Processing Record 47 of Set 8 | srednekolymsk
# Processing Record 48 of Set 8 | westport
# Processing Record 49 of Set 8 | allapalli
# Processing Record 50 of Set 8 | sao gabriel da cachoeira
# Processing Record 1 of Set 9 | betki
# City not found. Skipping...
# Processing Record 2 of Set 9 | ilulissat
# Processing Record 3 of Set 9 | nisia floresta
# Processing Record 4 of Set 9 | opuwo
# Processing Record 5 of Set 9 | calama
# Processing Record 6 of Set 9 | baruun-urt
# Processing Record 7 of Set 9 | hoquiam
# Processing Record 8 of Set 9 | dauphin
# Processing Record 9 of Set 9 | turda
# Processing Record 10 of Set 9 | santa ana
# Processing Record 11 of Set 9 | udachnyy
# Processing Record 12 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 9 | vestmannaeyjar
# Processing Record 14 of Set 9 | ambilobe
# Processing Record 15 of Set 9 | namatanai
# Processing Record 16 of Set 9 | nome
# Processing Record 17 of Set 9 | saint george
# Processing Record 18 of Set 9 | tarakan
# Processing Record 19 of Set 9 | lalibela
# Processing Record 20 of Set 9 | halifax
# Processing Record 21 of Set 9 | matay
# Processing Record 22 of Set 9 | huarmey
# Processing Record 23 of Set 9 | kenai
# Processing Record 24 of Set 9 | westerly
# Processing Record 25 of Set 9 | ancud
# Processing Record 26 of Set 9 | salmas
# Processing Record 27 of Set 9 | zhuhai
# Processing Record 28 of Set 9 | sheltozero
# Processing Record 29 of Set 9 | gazanjyk
# Processing Record 30 of Set 9 | tete
# Processing Record 31 of Set 9 | fairbanks
# Processing Record 32 of Set 9 | bagdarin
# Processing Record 33 of Set 9 | sibolga
# Processing Record 34 of Set 9 | belmonte
# Processing Record 35 of Set 9 | vostok
# Processing Record 36 of Set 9 | goderich
# Processing Record 37 of Set 9 | srikakulam
# Processing Record 38 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 9 | puerto quijarro
# Processing Record 40 of Set 9 | paldiski
# Processing Record 41 of Set 9 | seymchan
# Processing Record 42 of Set 9 | sept-iles
# Processing Record 43 of Set 9 | jalalabad
# Processing Record 44 of Set 9 | maldonado
# Processing Record 45 of Set 9 | wuwei
# Processing Record 46 of Set 9 | benito juarez
# Processing Record 47 of Set 9 | viedma
# Processing Record 48 of Set 9 | syracuse
# Processing Record 49 of Set 9 | payson
# Processing Record 50 of Set 9 | elko
# Processing Record 1 of Set 10 | hornepayne
# Processing Record 2 of Set 10 | menongue
# Processing Record 3 of Set 10 | kyshtovka
# Processing Record 4 of Set 10 | darnah
# Processing Record 5 of Set 10 | isoka
# Processing Record 6 of Set 10 | bilma
# Processing Record 7 of Set 10 | sorong
# Processing Record 8 of Set 10 | iralaya
# Processing Record 9 of Set 10 | asekeyevo
# Processing Record 10 of Set 10 | magdalena
# Processing Record 11 of Set 10 | trelew
# Processing Record 12 of Set 10 | ladario
# Processing Record 13 of Set 10 | kiunga
# Processing Record 14 of Set 10 | omoljica
# Processing Record 15 of Set 10 | iroquois falls
# Processing Record 16 of Set 10 | finnsnes
# Processing Record 17 of Set 10 | namibe
# Processing Record 18 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 10 | derbent
# Processing Record 20 of Set 10 | batticaloa
# Processing Record 21 of Set 10 | alice town
# Processing Record 22 of Set 10 | gigmoto
# Processing Record 23 of Set 10 | ardistan
# City not found. Skipping...
# Processing Record 24 of Set 10 | russell
# Processing Record 25 of Set 10 | ojitlan
# City not found. Skipping...
# Processing Record 26 of Set 10 | vila franca do campo
# Processing Record 27 of Set 10 | nanortalik
# Processing Record 28 of Set 10 | edd
# Processing Record 29 of Set 10 | acapulco
# Processing Record 30 of Set 10 | port augusta
# Processing Record 31 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 32 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 10 | moratuwa
# Processing Record 34 of Set 10 | santa isabel
# Processing Record 35 of Set 10 | manuk mangkaw
# Processing Record 36 of Set 10 | la rioja
# Processing Record 37 of Set 10 | varniai
# Processing Record 38 of Set 10 | kuybysheve
# Processing Record 39 of Set 10 | llallagua
# Processing Record 40 of Set 10 | boende
# Processing Record 41 of Set 10 | anadyr
# Processing Record 42 of Set 10 | high level
# Processing Record 43 of Set 10 | svetlogorsk
# Processing Record 44 of Set 10 | solnechnyy
# Processing Record 45 of Set 10 | boma
# Processing Record 46 of Set 10 | carlyle
# Processing Record 47 of Set 10 | nipawin
# Processing Record 48 of Set 10 | the valley
# Processing Record 49 of Set 10 | bubaque
# Processing Record 50 of Set 10 | tucurui
# Processing Record 1 of Set 11 | sungaipenuh
# Processing Record 2 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 3 of Set 11 | tarbagatay
# Processing Record 4 of Set 11 | san quintin
# Processing Record 5 of Set 11 | stromness
# Processing Record 6 of Set 11 | buenos aires
# Processing Record 7 of Set 11 | tres arroyos
# Processing Record 8 of Set 11 | ilhabela
# Processing Record 9 of Set 11 | banda aceh
# Processing Record 10 of Set 11 | veraval
# Processing Record 11 of Set 11 | copiapo
# Processing Record 12 of Set 11 | verkhnyaya inta
# Processing Record 13 of Set 11 | fort nelson
# Processing Record 14 of Set 11 | sofiysk
# City not found. Skipping...
# Processing Record 15 of Set 11 | changji
# Processing Record 16 of Set 11 | rudnogorsk
# Processing Record 17 of Set 11 | houston
# Processing Record 18 of Set 11 | broken hill
# Processing Record 19 of Set 11 | laje
# Processing Record 20 of Set 11 | miyako
# Processing Record 21 of Set 11 | craigieburn
# Processing Record 22 of Set 11 | jaciara
# Processing Record 23 of Set 11 | batagay
# Processing Record 24 of Set 11 | bambanglipuro
# Processing Record 25 of Set 11 | kukes
# Processing Record 26 of Set 11 | safwah
# City not found. Skipping...
# Processing Record 27 of Set 11 | cifuentes
# Processing Record 28 of Set 11 | siocon
# Processing Record 29 of Set 11 | aykhal
# Processing Record 30 of Set 11 | santander de quilichao
# Processing Record 31 of Set 11 | teruel
# Processing Record 32 of Set 11 | kodinsk
# Processing Record 33 of Set 11 | egvekinot
# Processing Record 34 of Set 11 | bayan
# Processing Record 35 of Set 11 | marienburg
# Processing Record 36 of Set 11 | komsomolskiy
# Processing Record 37 of Set 11 | stephenville
# Processing Record 38 of Set 11 | kulzeb
# City not found. Skipping...
# Processing Record 39 of Set 11 | riberalta
# Processing Record 40 of Set 11 | rawson
# Processing Record 41 of Set 11 | coihaique
# Processing Record 42 of Set 11 | biak
# Processing Record 43 of Set 11 | ishigaki
# Processing Record 44 of Set 11 | pringsewu
# Processing Record 45 of Set 11 | ussel
# Processing Record 46 of Set 11 | ouesso
# Processing Record 47 of Set 11 | dillon
# Processing Record 48 of Set 11 | guerrero negro
# Processing Record 49 of Set 11 | shingu
# Processing Record 50 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 1 of Set 12 | marfino
# Processing Record 2 of Set 12 | champerico
# Processing Record 3 of Set 12 | pathein
# Processing Record 4 of Set 12 | kodino
# Processing Record 5 of Set 12 | najran
# Processing Record 6 of Set 12 | outjo
# Processing Record 7 of Set 12 | quito
# Processing Record 8 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 9 of Set 12 | gushikawa
# Processing Record 10 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 11 of Set 12 | nicoya
# Processing Record 12 of Set 12 | tocopilla
# Processing Record 13 of Set 12 | evanston
# Processing Record 14 of Set 12 | saint-georges
# Processing Record 15 of Set 12 | jinxiang
# Processing Record 16 of Set 12 | rendeux
# Processing Record 17 of Set 12 | beroroha
# Processing Record 18 of Set 12 | marawi
# Processing Record 19 of Set 12 | kjollefjord
# Processing Record 20 of Set 12 | dunmore east
# Processing Record 21 of Set 12 | mentougou
# Processing Record 22 of Set 12 | hegang
# Processing Record 23 of Set 12 | manokwari
# Processing Record 24 of Set 12 | parakou
# Processing Record 25 of Set 12 | port lincoln
# Processing Record 26 of Set 12 | tura
# Processing Record 27 of Set 12 | matamoros
# Processing Record 28 of Set 12 | kem
# Processing Record 29 of Set 12 | ballina
# Processing Record 30 of Set 12 | turbat
# Processing Record 31 of Set 12 | mazyr
# Processing Record 32 of Set 12 | na wa
# Processing Record 33 of Set 12 | asau
# Processing Record 34 of Set 12 | cootamundra
# Processing Record 35 of Set 12 | bure
# Processing Record 36 of Set 12 | zelenoborsk
# Processing Record 37 of Set 12 | asyut
# Processing Record 38 of Set 12 | moussoro
# Processing Record 39 of Set 12 | orchard homes
# Processing Record 40 of Set 12 | plouzane
# Processing Record 41 of Set 12 | port hedland
# Processing Record 42 of Set 12 | antropovo
# Processing Record 43 of Set 12 | real
# Processing Record 44 of Set 12 | merced
# Processing Record 45 of Set 12 | enshi
# Processing Record 46 of Set 12 | cheremukhovo
# Processing Record 47 of Set 12 | chernihiv
# Processing Record 48 of Set 12 | severo-yeniseyskiy
# Processing Record 49 of Set 12 | vila velha
# Processing Record 50 of Set 12 | buala
# Processing Record 1 of Set 13 | grindavik
# Processing Record 2 of Set 13 | sechura
# Processing Record 3 of Set 13 | altayskoye
# Processing Record 4 of Set 13 | umm lajj
# Processing Record 5 of Set 13 | zhanaozen
# Processing Record 6 of Set 13 | balkanabat
# Processing Record 7 of Set 13 | ubinskoye
# Processing Record 8 of Set 13 | mayya
# Processing Record 9 of Set 13 | botwood
# Processing Record 10 of Set 13 | ngunguru
# Processing Record 11 of Set 13 | cap malheureux
# Processing Record 12 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 13 of Set 13 | mount darwin
# Processing Record 14 of Set 13 | falcoiu
# Processing Record 15 of Set 13 | nur
# Processing Record 16 of Set 13 | fereydun kenar
# Processing Record 17 of Set 13 | otaru
# Processing Record 18 of Set 13 | zhigansk
# Processing Record 19 of Set 13 | nagornyy
# Processing Record 20 of Set 13 | tazovskiy
# Processing Record 21 of Set 13 | lakes entrance
# Processing Record 22 of Set 13 | tabarqah
# City not found. Skipping...
# Processing Record 23 of Set 13 | kupino
# Processing Record 24 of Set 13 | pisco
# Processing Record 25 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 26 of Set 13 | castries
# Processing Record 27 of Set 13 | egersund
# Processing Record 28 of Set 13 | ponferrada
# Processing Record 29 of Set 13 | sturgeon falls
# Processing Record 30 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 13 | nurota
# Processing Record 32 of Set 13 | jacareacanga
# Processing Record 33 of Set 13 | takoradi
# Processing Record 34 of Set 13 | basavana bagevadi
# Processing Record 35 of Set 13 | vallenar
# Processing Record 36 of Set 13 | yerbogachen
# Processing Record 37 of Set 13 | iquique
# Processing Record 38 of Set 13 | afsin
# Processing Record 39 of Set 13 | kommunar
# Processing Record 40 of Set 13 | thaba nchu
# Processing Record 41 of Set 13 | baherden
# Processing Record 42 of Set 13 | quatre cocos
# Processing Record 43 of Set 13 | canutama
# Processing Record 44 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 45 of Set 13 | payo
# Processing Record 46 of Set 13 | rock sound
# Processing Record 47 of Set 13 | bukachacha
# Processing Record 48 of Set 13 | nhulunbuy
# Processing Record 49 of Set 13 | vilhena
# Processing Record 50 of Set 13 | atar
# Processing Record 1 of Set 14 | la sarre
# Processing Record 2 of Set 14 | asayita
# City not found. Skipping...
# Processing Record 3 of Set 14 | choix
# Processing Record 4 of Set 14 | pozo colorado
# Processing Record 5 of Set 14 | saryg-sep
# Processing Record 6 of Set 14 | muli
# Processing Record 7 of Set 14 | lugus
# Processing Record 8 of Set 14 | tastur
# Processing Record 9 of Set 14 | broome
# Processing Record 10 of Set 14 | mafeteng
# Processing Record 11 of Set 14 | aleksandrovskoye
# Processing Record 12 of Set 14 | algiers
# Processing Record 13 of Set 14 | mana
# Processing Record 14 of Set 14 | wanning
# Processing Record 15 of Set 14 | andenes
# Processing Record 16 of Set 14 | igrim
# Processing Record 17 of Set 14 | balboa
# Processing Record 18 of Set 14 | oranjemund
# Processing Record 19 of Set 14 | ambunti
# Processing Record 20 of Set 14 | vytegra
# Processing Record 21 of Set 14 | jackson
# Processing Record 22 of Set 14 | novouzensk
# Processing Record 23 of Set 14 | amalapuram
# Processing Record 24 of Set 14 | yumen
# Processing Record 25 of Set 14 | viet tri
# Processing Record 26 of Set 14 | flinders
# Processing Record 27 of Set 14 | mehamn
# Processing Record 28 of Set 14 | trairi
# Processing Record 29 of Set 14 | severomorsk
# Processing Record 30 of Set 14 | san patricio
# Processing Record 31 of Set 14 | jutai
# Processing Record 32 of Set 14 | obo
# Processing Record 33 of Set 14 | bandarbeyla
# Processing Record 34 of Set 14 | camocim
# Processing Record 35 of Set 14 | graciano sanchez
# Processing Record 36 of Set 14 | shenzhen
# Processing Record 37 of Set 14 | talas
# Processing Record 38 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 39 of Set 14 | burnie
# Processing Record 40 of Set 14 | asahi
# Processing Record 41 of Set 14 | richard toll
# City not found. Skipping...
# Processing Record 42 of Set 14 | nizhneangarsk
# Processing Record 43 of Set 14 | charlestown
# Processing Record 44 of Set 14 | ono
# Processing Record 45 of Set 14 | necochea
# Processing Record 46 of Set 14 | beringovskiy
# Processing Record 47 of Set 14 | caconda
# Processing Record 48 of Set 14 | faya
# Processing Record 49 of Set 14 | apaxtla
# City not found. Skipping...
# Processing Record 50 of Set 14 | kondinskoye
# Processing Record 1 of Set 15 | jacqueville
# Processing Record 2 of Set 15 | aragarcas
# Processing Record 3 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 4 of Set 15 | lamu
# Processing Record 5 of Set 15 | ajdabiya
# Processing Record 6 of Set 15 | kinshasa
# Processing Record 7 of Set 15 | yulara
# Processing Record 8 of Set 15 | misratah
# Processing Record 9 of Set 15 | san matias
# Processing Record 10 of Set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 11 of Set 15 | matane
# Processing Record 12 of Set 15 | sabha
# Processing Record 13 of Set 15 | sharan
# Processing Record 14 of Set 15 | ust-maya
# Processing Record 15 of Set 15 | riyadh
# Processing Record 16 of Set 15 | portland
# Processing Record 17 of Set 15 | lazarev
# Processing Record 18 of Set 15 | bardiyah
# Processing Record 19 of Set 15 | moose factory
# Processing Record 20 of Set 15 | mitu
# Processing Record 21 of Set 15 | ola
# Processing Record 22 of Set 15 | iranduba
# Processing Record 23 of Set 15 | placerville
# Processing Record 24 of Set 15 | port blair
# Processing Record 25 of Set 15 | arman
# Processing Record 26 of Set 15 | vardo
# Processing Record 27 of Set 15 | uniontown
# Processing Record 28 of Set 15 | kaitong
# Processing Record 29 of Set 15 | dolores
# Processing Record 30 of Set 15 | noshiro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Hasaki      JP  35.7333  140.8333     79.20        84         100
# 1        Rikitea      PF -23.1203 -134.9692     73.49        68           0
# 2        Qaanaaq      GL  77.4840  -69.3632     38.32        98         100
# 3          Pevek      RU  69.7008  170.3133     40.91        88         100
# 4       Hastings      GB  50.8552    0.5729     64.33        80          93
# 5         Golden      US  39.7555 -105.2211     73.38        75          75
# 6   Punta Arenas      CL -53.1500  -70.9167     35.71       100          90
# 7       Paracatu      BR -17.2222  -46.8747     63.46        53           0
# 8         Touros      BR  -5.1989  -35.4608     76.10        84          12
# 9  Mar Del Plata      AR -38.0023  -57.5575     51.87        72         100
#
#    Wind Speed Current description
# 0        7.83     overcast clouds
# 1        8.10           clear sky
# 2        4.81          light rain
# 3        3.40     overcast clouds
# 4        9.73     overcast clouds
# 5        3.00       broken clouds
# 6        3.44                mist
# 7        2.35           clear sky
# 8       12.12          few clouds
# 9        3.00     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
